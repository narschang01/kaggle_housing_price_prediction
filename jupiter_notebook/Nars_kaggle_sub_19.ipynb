# %% [markdown]
# # About NarsLKaggle_sub_17_Interaction_features
# - This is the Jupyter notebook of the 17th model along the way.
# - The prediction of this model is produce the best score among all 17 models.
# - This model begins with loading data from **df_train_sub9.csv'**
#     - The neighborhoor filed is dummied and included in the feature list
#     - It also includes a new field called nb_ranking
#         - NB_ranking is a manually assigned numeric field
#         - The number assigned is based on the highest and lowest price range of the neighborhood.
#         - By adding this field, the intention is to use this filed with other field to exemine the interaction between location, square footage, and house quality.
# - In this model, there is a list of interact features added to the dataset from earlier models, including:
#     - 'fbxgrla'
#     -

# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

pd.options.display.max_columns = 120
pd.options.display.max_rows = 3000

# %% [markdown]
# # Loading data

# %%
df = pd.read_csv('../project_2/df_train_sub9.csv')

# %%
df.head(2)
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           0.0     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
#
#   lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
#
#   condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
#
#    year_built  year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
#
#   electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area pool_qc  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
#
#   fence misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice  \
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
#
#    neighborhood_Blueste  neighborhood_BrDale  neighborhood_BrkSide  \
# 0                     0                    0                     0
# 1                     0                    0                     0
#
#    neighborhood_ClearCr  neighborhood_CollgCr  neighborhood_Crawfor  \
# 0                     0                     0                     0
# 1                     0                     0                     0
#
#    neighborhood_Edwards  neighborhood_Gilbert  neighborhood_Greens  \
# 0                     0                     0                    0
# 1                     0                     0                    0
#
#    neighborhood_GrnHill  neighborhood_IDOTRR  neighborhood_Landmrk  \
# 0                     0                    0                     0
# 1                     0                    0                     0
#
#    neighborhood_MeadowV  neighborhood_Mitchel  neighborhood_NAmes  \
# 0                     0                     0                   0
# 1                     0                     0                   0
#
#    neighborhood_NPkVill  neighborhood_NWAmes  neighborhood_NoRidge  \
# 0                     0                    0                     0
# 1                     0                    0                     0
#
#    neighborhood_NridgHt  neighborhood_OldTown  neighborhood_SWISU  \
# 0                     0                     0                   0
# 1                     0                     0                   0
#
#    neighborhood_Sawyer  neighborhood_SawyerW  neighborhood_Somerst  \
# 0                    1                     0                     0
# 1                    0                     1                     0
#
#    neighborhood_StoneBr  neighborhood_Timber  neighborhood_Veenker  fbxgrla  \
# 0                     0                    0                     0     2958
# 1                     0                    0                     0     4244
#
#    frxgrla  nb_ranking  nbrkxgla
# 0        0         1.4    2070.6
# 1     2122         2.0    4244.0

# %%
df.shape
# Out:
# (2050, 112)

# %% [markdown]
# # Handle null values

# %%
df.describe()
# Out:
0.000000
# 25%                0.000000             0.000000              0.000000
# 50%                0.000000             0.000000              0.000000
# 75%                0.000000             0.000000              0.000000
# max                1.000000             1.000000              1.000000
#
#        neighborhood_NridgHt  neighborhood_OldTown  neighborhood_SWISU  \
# count           2050.000000           2050.000000          2050.00000
# mean               0.059512              0.079512             0.01561
# std                0.236639              0.270603             0.12399
# min                0.000000              0.000000             0.00000
# 25%                0.000000              0.000000             0.00000
# 50%                0.000000              0.000000             0.00000
# 75%                0.000000              0.000000             0.00000
# max                1.000000              1.000000             1.00000
#
#        neighborhood_Sawyer  neighborhood_SawyerW  neighborhood_Somerst  \
# count          2050.000000           2050.000000           2050.000000
# mean              0.054146              0.042439              0.063415
# std               0.226361              0.201638              0.243767
# min               0.000000              0.000000              0.000000
# 25%               0.000000              0.000000              0.000000
# 50%               0.000000              0.000000              0.000000
# 75%               0.000000              0.000000              0.000000
# max               1.000000              1.000000              1.000000
#
#        neighborhood_StoneBr  neighborhood_Timber  neighborhood_Veenker  \
# count           2050.000000          2050.000000           2050.000000
# mean               0.018537             0.023415              0.008293
# std                0.134914             0.151253              0.090708
# min                0.000000             0.000000              0.000000
# 25%                0.000000             0.000000              0.000000
# 50%                0.000000             0.000000              0.000000
# 75%                0.000000             0.000000              0.000000
# max                1.000000             1.000000              1.000000
#
#             fbxgrla       frxgrla   nb_ranking      nbrkxgla
# count   2050.000000   2050.000000  2050.000000   2050.000000
# mean    2535.272195   1033.008293     2.022415   3153.802293
# std     1556.338007   1300.991420     0.537710   1676.941192
# min        0.000000      0.000000     1.000000    450.900000
# 25%     1154.000000      0.000000     1.700000   1966.250000
# 50%     2560.000000    944.500000     1.900000   2811.050000
# 75%     3418.000000   1694.000000     2.500000   3936.600000
# max    11460.000000  16926.000000     3.600000  12204.000000

# %% [markdown]
# df['fbxgrla'] = df['full_bath'] * df['gr_liv_area']

# %% [markdown]
# df['frxgrla'] = df['fireplaces'] * df['gr_liv_area']

# %% [markdown]
# df.shape

# %%
df['ovqxgla'] = df['overall_qual'] * df['gr_liv_area']

# %%
df['ovqxnbr'] = df['overall_qual'] * df['nb_ranking']

# %% [markdown]
# # Clean-up and EDA

# %%
# sns.heatmap(df.corr()[['bpm']].sort_values('bpm'), annot = True)
plt.figure(figsize = (15, 25))

sns.heatmap(df.corr()[['saleprice']].sort_values('saleprice'), annot = True);

# %%
sns.pairplot(df, y_vars=['saleprice'], x_vars=['nbrkxgla','overall_qual', 'nb_ranking', 'gr_liv_area', 'fbxgrla'])

# %%
sns.pairplot(df, y_vars=['saleprice'], x_vars=['garage_area', 'total_bsmt_sf','1st_flr_sf', 'frxgrla', 'ovqxgla'])

# %%
sns.pairplot(df, y_vars=['saleprice'], x_vars=['year_built', 'year_remod/add', 'totrms_abvgrd', 'garage_cars', 'ovqxnbr'])

# %% [markdown]
# nb_dum_list = ['neighborhood_Blueste', 'neighborhood_BrDale', 'neighborhood_BrkSide', 'neighborhood_ClearCr',
#                'neighborhood_CollgCr', 'neighborhood_Crawfor', 'neighborhood_Edwards', 'neighborhood_Gilbert',
#                'neighborhood_Greens', 'neighborhood_GrnHill', 'neighborhood_IDOTRR', 'neighborhood_Landmrk',
#                'neighborhood_MeadowV', 'neighborhood_Mitchel', 'neighborhood_NAmes', 'neighborhood_NPkVill',
#                'neighborhood_NWAmes', 'neighborhood_NoRidge', 'neighborhood_NridgHt', 'neighborhood_OldTown',
#                'neighborhood_SWISU', 'neighborhood_Sawyer', 'neighborhood_SawyerW', 'neighborhood_Somerst',
#                'neighborhood_StoneBr', 'neighborhood_Timber','neighborhood_Veenker']

# %% [markdown]
# nb_name = []
# for nb in nb_dum_list:
#     nb.split('_')[1]
#     nb_name.append(nb.split('_')[1])
#
# nb_name

# %% [markdown]
# df['nb_ranking'] = df['neighborhood'].map({'Blueste':1.6, 'BrDale':1, 'BrkSide': 1.35, 'ClearCr': 2.35,
#                                           'CollgCr':2.5, 'Crawfor':2.5, 'Edwards': 1.7, 'Gilbert': 2.1,
#                                            'Greens': 1.95, 'GrnHill':3, 'IDOTRR':1.05, 'Landmrk':1.5,
#                                            'MeadowV':1.25, 'Mitchel':1.45, 'NAmes':1.9, 'NPkVill':1.35,
#                                            'NWAmes':2.05, 'NoRidge':3.4, 'NridgHt':2.7, 'OldTown':1.85,
#                                            'SWISU':1.45, 'Sawyer':1.4, 'SawyerW':2, 'Somerst':2.15,
#                                            'StoneBr':3.6, 'Timber':2.85, 'Veenker':2.6, 'Blmngtn':2.1})

# %% [markdown]
# df['nb_ranking'].sort_values().value_counts()

# %%
df['carsxara'] = df['garage_cars'] * df['garage_area']

# %% [markdown]
# df['nbrkxgla'].isnull().sum()

# %% [markdown]
# df[df['nbrkxgla'].isnull()]

# %% [markdown]
# df.shape

# %% [markdown]
# df.head(3)

# %% [markdown]
# <font size=3 color= green><b>The following three lines of code are for neighborhood reviewing.</b></font>

# %% [markdown]
# sns.pairplot(df, y_vars=['saleprice'], x_vars=['neighborhood_BrkSide'])

# %% [markdown]
# sns.pairplot(df, y_vars=['saleprice'], x_vars=['neighborhood_Timber',
#  'neighborhood_Veenker'])

# %% [markdown]
# df['garage_finish'].describe()

# %%
df['carsxara'].value_counts()
# Out:
# 0.0       113
# 1152.0     69
# 880.0      67
# 968.0      52
# 240.0      45
# 1056.0     45
# 800.0      43
# 288.0      42
# 960.0      38
# 264.0      32
# 308.0      32
# 280.0      23
# 336.0      18
# 924.0      18
# 1008.0     17
# 312.0      16
# 840.0      16
# 216.0      16
# 1144.0     15
# 180.0      14
# 1248.0     14
# 384.0      13
# 1344.0     13
# 1012.0     13
# 1100.0     13
# 1050.0     12
# 352.0      12
# 1128.0     12
# 956.0      12
# 300.0      11
# 1440.0     10
# 286.0      10
# 1080.0     10
# 297.0       9
# 990.0       9
# 1176.0      9
# 1084.0      9
# 270.0       8
# 964.0       8
# 1156.0      8
# 940.0       8
# 1040.0      8
# 944.0       8
# 920.0       8
# 1078.0      8
# 948.0       7
# 864.0       7
# 200.0       7
# 1058.0      7
# 720.0       7
# 900.0       7
# 294.0       7
# 980.0       7
# 862.0       7
# 946.0       6
# 252.0       6
# 786.0       6
# 1320.0      6
# 860.0       6
# 1120.0      6
# 1980.0      6
# 922.0       6
# 882.0       6
# 1104.0      6
# 1004.0      6
        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1711  2237  910201180           70        RM          50.0      9060   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 1711   NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1711       IDOTRR        Norm        Norm      1Fam      2Story             5
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1711             6        1923            1999      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 1711      Wd Sdng      Plywood         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1711         TA     BrkTil        Gd        TA            No            ALQ
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1711         548.0            Unf           0.0        311.0          859.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1711    GasA         Ex           Y      SBrkr         942         886
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1711                0         1828             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1711          0              3              1           Gd              6
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1711        Typ           0          NaN      Detchd            0.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1711           NaN          NaN          0.0         NaN         NaN
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1711           Y           174              0             212           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 1711             0          0     NaN  MnPrv          NaN         0        3
#
#       yr_sold sale_type  saleprice  neighborhood_Blueste  neighborhood_BrDale  \
# 1711     2007       WD      150909                     0                    0
#
#       neighborhood_BrkSide  neighborhood_ClearCr  neighborhood_CollgCr  \
# 1711                     0                     0                     0
#
#       neighborhood_Crawfor  neighborhood_Edwards  neighborhood_Gilbert  \
# 1711                     0                     0                     0
#
#       neighborhood_Greens  neighborhood_GrnHill  neighborhood_IDOTRR  \
# 1711                    0                     0                    1
#
#       neighborhood_Landmrk  neighborhood_MeadowV  neighborhood_Mitchel  \
# 1711                     0                     0                     0
#
#       neighborhood_NAmes  neighborhood_NPkVill  neighborhood_NWAmes  \
# 1711                   0                     0                    0
#
#       neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# 1711                     0                     0                     0
#
#       neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# 1711                   0                    0                     0
#
#       neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# 1711                     0                     0                    0
#
#       neighborhood_Veenker  fbxgrla  frxgrla  nb_ranking  nbrkxgla  ovqxgla  \
# 1711                     0     3656        0        1.05    1919.4     9140
#
#       ovqxnbr  carsxara
# 1711     5.25       NaN

# %%
df['carsxara'] = df['carsxara'].replace(np.nan, 0)

# %% [markdown]
# <font size=3 color= green><b>The following three lines of code are for single column reviewing.</b></font>

# %% [markdown]
# - Should I drop df['garage_yr_blt'] == 0?
# - drop df['mas_vnr_area'].isnull()? x22

# %% [markdown]
# df['bsmt_full_bath'] = df['bsmt_full_bath'].fillna(0)

# %% [markdown]
# df['bsmt_full_bath'].isnull().sum()

# %% [markdown]
# df['bsmt_full_bath'].describe()

# %% [markdown]
# df['full_bath'].value_counts()

# %%
df.to_csv('df_train_sub119.csv', index = False)

# %% [markdown]
# # Define Feature Matrix & Target

# %%
features = ['nbrkxgla','overall_qual', 'nb_ranking', 'gr_liv_area', 'fbxgrla', 'total_bsmt_sf','ovqxgla', 'ovqxnbr',
            '1st_flr_sf', 'frxgrla', 'year_built', 'year_remod/add', 'totrms_abvgrd', 'carsxara', 'neighborhood_Blueste',
 'neighborhood_BrDale',
 'neighborhood_BrkSide',
 'neighborhood_ClearCr',
 'neighborhood_CollgCr',
 'neighborhood_Crawfor',
 'neighborhood_Edwards',
 'neighborhood_Gilbert',
 'neighborhood_Greens',
 'neighborhood_GrnHill',
 'neighborhood_IDOTRR',
 'neighborhood_Landmrk',
 'neighborhood_MeadowV',
 'neighborhood_Mitchel',
 'neighborhood_NAmes',
 'neighborhood_NPkVill',
 'neighborhood_NWAmes',
 'neighborhood_NoRidge',
 'neighborhood_NridgHt',
 'neighborhood_OldTown',
 'neighborhood_SWISU',
 'neighborhood_Sawyer',
 'neighborhood_SawyerW',
 'neighborhood_Somerst',
 'neighborhood_StoneBr',
 'neighborhood_Timber',
 'neighborhood_Veenker']

# %%
df[features].isnull().sum()
# Out:
# nbrkxgla                0
# overall_qual            0
# nb_ranking              0
# gr_liv_area             0
# fbxgrla                 0
# total_bsmt_sf           0
# ovqxgla                 0
# ovqxnbr                 0
# 1st_flr_sf              0
# frxgrla                 0
# year_built              0
# year_remod/add          0
# totrms_abvgrd           0
# carsxara                0
# neighborhood_Blueste    0
# neighborhood_BrDale     0
# neighborhood_BrkSide    0
# neighborhood_ClearCr    0
# neighborhood_CollgCr    0
# neighborhood_Crawfor    0
# neighborhood_Edwards    0
# neighborhood_Gilbert    0
# neighborhood_Greens     0
# neighborhood_GrnHill    0
# neighborhood_IDOTRR     0
# neighborhood_Landmrk    0
# neighborhood_MeadowV    0
# neighborhood_Mitchel    0
# neighborhood_NAmes      0
# neighborhood_NPkVill    0
# neighborhood_NWAmes     0
# neighborhood_NoRidge    0
# neighborhood_NridgHt    0
# neighborhood_OldTown    0
# neighborhood_SWISU      0
# neighborhood_Sawyer     0
# neighborhood_SawyerW    0
# neighborhood_Somerst    0
# neighborhood_StoneBr    0
# neighborhood_Timber     0
# neighborhood_Veenker    0
# dtype: int64

# %%
y = df['saleprice']
X = df[features]

# %% [markdown]
# #### Train-Test-Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, random_state = 308)

# %% [markdown]
# ## Standardscaler transform

# %% [markdown]
# ss = StandardScaler()

# %% [markdown]
# ss.fit(X_train)

# %% [markdown]
# X_train_sc = ss.transform(X_train)

# %% [markdown]
# X_valid_sc = ss.transform(X_valid)

# %% [markdown]
# #### Instantiate, Fit, Score Model

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
cross_val_score(lr, X_train, y_train)
# Out:
# array([0.85365137, 0.84457261, 0.88146293, 0.88160357, 0.72965096])

# %%
cross_val_score(lr, X_train, y_train).mean()
# Out:
# 0.8381882912894874

# %%
cross_val_score(lr, X_valid, y_valid)
# Out:
# array([0.839167  , 0.20647506, 0.83447992, 0.88695305, 0.87483693])

# %%
cross_val_score(lr, X_valid, y_valid).mean()
# Out:
# 0.728382393387901

# %%
lr.score(X_train, y_train), lr.score(X_valid, y_valid)
# Out:
# (0.8729070850273952, 0.8416254410276272)

# %%
list(zip(X.columns, lr.coef_))

# %% [markdown]
# #### Now we have a model object, and we can run our df_test data through it

# %% [markdown]
# # Prep df_test data

# %%
df_test = pd.read_csv('../project_2/df_test_sub9.csv')

# %%
df_test.shape
# Out:
# (878, 115)

# %%
df_test.describe()
# Out:
#                 id           pid  ms_subclass  lot_frontage       lot_area  \
# count   878.000000  8.780000e+02   878.000000    718.000000     878.000000
# mean   1444.749431  7.162867e+08    58.268793     69.545961   10307.033030
# std     850.838263  1.889103e+08    42.235407     23.533945   10002.674602
# min       2.000000  5.263021e+08    20.000000     21.000000    1477.000000
# 25%     692.250000  5.284841e+08    20.000000     59.000000    7297.250000
# 50%    1433.000000  5.354542e+08    50.000000     68.000000    9446.000000
# 75%    2197.500000  9.071904e+08    70.000000     80.000000   11589.000000
# max    2928.000000  1.007100e+09   190.000000    182.000000  215245.000000
#
#        overall_qual  overall_cond   year_built  year_remod/add  mas_vnr_area  \
# count    878.000000    878.000000   878.000000      878.000000    877.000000
# mean       6.050114      5.566059  1970.492027     1984.417995    106.236032
# std        1.369065      1.128903    30.395895       20.450725    187.158908
# min        2.000000      1.000000  1880.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1954.000000     1967.000000      0.000000
# 50%        6.000000      5.000000  1972.000000     1992.000000      0.000000
# 75%        7.000000      6.000000  1999.750000     2003.000000    172.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1378.000000
#
#        bsmtfin_sf_1  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf   1st_flr_sf  \
# count    878.000000    878.000000   878.000000     878.000000   878.000000
# mean     441.328018     53.896355   539.133257    1034.357631  1145.787016
# std      438.457329    178.632355   426.172161     413.446291   375.264111
# min        0.000000      0.000000     0.000000       0.000000   407.000000
# 25%        0.000000      0.000000   216.000000     789.000000   864.000000
# 50%      373.000000      0.000000   452.000000     975.000000  1063.000000
# 75%      734.750000      0.000000   780.000000    1247.000000  1358.000000
# max     2288.000000   1526.000000  2046.000000    2630.000000  2674.000000
#
#         2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# count   878.000000       878.000000   878.000000      878.000000
# mean    348.398633         2.728929  1496.914579        0.439636
# std     432.985566        32.572548   506.468967        0.529948
# min       0.000000         0.000000   407.000000        0.000000
# 25%       0.000000         0.000000  1114.000000        0.000000
# 50%       0.000000         0.000000  1436.000000        0.000000
# 75%     720.000000         0.000000  1779.000000        1.000000
# max    2065.000000       481.000000  4476.000000        2.000000
#
#        bsmt_half_bath   full_bath   half_bath  bedroom_abvgr  kitchen_abvgr  \
# count      878.000000  878.000000  878.000000     878.000000     878.000000
# mean         0.055809    1.539863    0.398633       2.879271       1.047836
# std          0.229683    0.559060    0.505927       0.830712       0.223966
# min          0.000000    0.000000    0.000000       0.000000       0.000000
# 25%          0.000000    1.000000    0.000000       2.000000       1.000000
# 50%          0.000000    2.000000    0.000000       3.000000       1.000000
# 75%          0.000000    2.000000    1.000000       3.000000       1.000000
# max          1.000000    4.000000    2.000000       6.000000       3.000000
#
# 75%              0.000000              0.000000             0.000000
# max              1.000000              1.000000             1.000000
#
#        neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# count            878.000000            878.000000             878.00000
# mean               0.026196              0.050114               0.08656
# std                0.159809              0.218304               0.28135
# min                0.000000              0.000000               0.00000
# 25%                0.000000              0.000000               0.00000
# 50%                0.000000              0.000000               0.00000
# 75%                0.000000              0.000000               0.00000
# max                1.000000              1.000000               1.00000
#
#        neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# count          878.000000           878.000000            878.000000
# mean             0.018223             0.045558              0.043280
# std              0.133834             0.208644              0.203603
# min              0.000000             0.000000              0.000000
# 25%              0.000000             0.000000              0.000000
# 50%              0.000000             0.000000              0.000000
# 75%              0.000000             0.000000              0.000000
# max              1.000000             1.000000              1.000000
#
#        neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# count            878.000000            878.000000           878.000000
# mean               0.059226              0.014806             0.027335
# std                0.236181              0.120846             0.163150
# min                0.000000              0.000000             0.000000
# 25%                0.000000              0.000000             0.000000
# 50%                0.000000              0.000000             0.000000
# 75%                0.000000              0.000000             0.000000
# max                1.000000              1.000000             1.000000
#
#        neighborhood_Veenker  neighborhood_GrnHill  neighborhood_Landmrk  \
# count            878.000000                 878.0                 878.0
# mean               0.007973                   0.0                   0.0
# std                0.088984                   0.0                   0.0
# min                0.000000                   0.0                   0.0
# 25%                0.000000                   0.0                   0.0
# 50%                0.000000                   0.0                   0.0
# 75%                0.000000                   0.0                   0.0
# max                1.000000                   0.0                   0.0
#
#                y_hat       fbxgrla      frxgrla  nb_ranking      nbrkxgla  \
# count     878.000000    878.000000   878.000000  878.000000    878.000000
# mean   179421.778172   2491.335991  1079.200456    2.033200   3165.409966
# std     70486.712759   1637.616102  1326.089783    0.529209   1713.371754
# min      7207.479659      0.000000     0.000000    1.000000    673.050000
# 25%    130831.867358   1131.250000     0.000000    1.700000   1965.800000
# 50%    166538.522171   2367.000000   947.000000    1.950000   2846.475000
# 75%    219027.769789   3438.500000  1769.250000    2.500000   3893.337500
# max    513595.119497  13428.000000  8952.000000    3.600000  15218.400000
#
#             ovqxgla     ovqxnbr     carsxara
# count    878.000000  878.000000   878.000000
# mean    9455.474943   12.749886   960.141230
# std     4953.032895    5.733252   729.644365
# min      814.000000    2.700000     0.000000
# 25%     5783.250000    8.500000   324.500000
# 50%     8484.000000   12.000000   929.000000
# 75%    11859.500000   15.050000  1152.000000
# max    44760.000000   34.000000  5952.000000

# %%
df_test['carsxara'] = df_test['garage_cars'] * df_test['garage_area']

# %%
df_test['ovqxgla'] = df_test['overall_qual'] * df_test['gr_liv_area']

# %%
df_test['ovqxnbr'] = df_test['overall_qual'] * df_test['nb_ranking']

# %% [markdown]
# df_test['nb_ranking'] = df_test['neighborhood'].map({'Blueste':1.6, 'BrDale':1, 'BrkSide': 1.35, 'ClearCr': 2.35,
#                                           'CollgCr':2.5, 'Crawfor':2.5, 'Edwards': 1.7, 'Gilbert': 2.1,
#                                            'Greens': 1.95, 'GrnHill':3, 'IDOTRR':1.05, 'Landmrk':1.5,
#                                            'MeadowV':1.25, 'Mitchel':1.45, 'NAmes':1.9, 'NPkVill':1.35,
#                                            'NWAmes':2.05, 'NoRidge':3.4, 'NridgHt':2.7, 'OldTown':1.85,
#                                            'SWISU':1.45, 'Sawyer':1.4, 'SawyerW':2, 'Somerst':2.15,
#                                            'StoneBr':3.6, 'Timber':2.85, 'Veenker':2.6, 'Blmngtn':2.1})

# %% [markdown]
# df_test['nb_ranking'].sort_values().value_counts()

# %% [markdown]
# df_test['nbrkxgla'] = df_test['nb_ranking'] * df_test['gr_liv_area']

# %% [markdown]
# df_test['fbxgrla'] = df_test['full_bath'] * df_test['gr_liv_area']

# %% [markdown]
# df_test['frxgrla'] = df_test['fireplaces'] * df_test['gr_liv_area']

# %%
df_test[features].isnull().sum()
# Out:
# nbrkxgla                0
# overall_qual            0
# nb_ranking              0
# gr_liv_area             0
# fbxgrla                 0
# total_bsmt_sf           0
# ovqxgla                 0
# ovqxnbr                 0
# 1st_flr_sf              0
# frxgrla                 0
# year_built              0
# year_remod/add          0
# totrms_abvgrd           0
# carsxara                0
# neighborhood_Blueste    0
# neighborhood_BrDale     0
# neighborhood_BrkSide    0
# neighborhood_ClearCr    0
# neighborhood_CollgCr    0
# neighborhood_Crawfor    0
# neighborhood_Edwards    0
# neighborhood_Gilbert    0
# neighborhood_Greens     0
# neighborhood_GrnHill    0
# neighborhood_IDOTRR     0
# neighborhood_Landmrk    0
# neighborhood_MeadowV    0
# neighborhood_Mitchel    0
# neighborhood_NAmes      0
# neighborhood_NPkVill    0
# neighborhood_NWAmes     0
# neighborhood_NoRidge    0
# neighborhood_NridgHt    0
# neighborhood_OldTown    0
# neighborhood_SWISU      0
# neighborhood_Sawyer     0
# neighborhood_SawyerW    0
# neighborhood_Somerst    0
# neighborhood_StoneBr    0
# neighborhood_Timber     0
# neighborhood_Veenker    0
# dtype: int64

# %%
df_test.to_csv('df_test_sub19.csv', index = False)

# %%
df_test.shape
# Out:
# (878, 115)

# %% [markdown]
# #### Make sure there aren't any nulls in the columns we used in the model:

# %%
df_test[features].isnull().sum()
# Out:
# nbrkxgla                0
# overall_qual            0
# nb_ranking              0
# gr_liv_area             0
# fbxgrla                 0
# total_bsmt_sf           0
# ovqxgla                 0
# ovqxnbr                 0
# 1st_flr_sf              0
# frxgrla                 0
# year_built              0
# year_remod/add          0
# totrms_abvgrd           0
# carsxara                0
# neighborhood_Blueste    0
# neighborhood_BrDale     0
# neighborhood_BrkSide    0
# neighborhood_ClearCr    0
# neighborhood_CollgCr    0
# neighborhood_Crawfor    0
# neighborhood_Edwards    0
# neighborhood_Gilbert    0
# neighborhood_Greens     0
# neighborhood_GrnHill    0
# neighborhood_IDOTRR     0
# neighborhood_Landmrk    0
# neighborhood_MeadowV    0
# neighborhood_Mitchel    0
# neighborhood_NAmes      0
# neighborhood_NPkVill    0
# neighborhood_NWAmes     0
# neighborhood_NoRidge    0
# neighborhood_NridgHt    0
# neighborhood_OldTown    0
# neighborhood_SWISU      0
# neighborhood_Sawyer     0
# neighborhood_SawyerW    0
# neighborhood_Somerst    0
# neighborhood_StoneBr    0
# neighborhood_Timber     0
# neighborhood_Veenker    0
# dtype: int64

# %%
list(df_test.columns)
# Out:
# ['id',
#  'pid',
#  'ms_subclass',
#  'ms_zoning',
#  'lot_frontage',
#  'lot_area',
#  'street',
#  'alley',
#  'lot_shape',
#  'land_contour',
#  'utilities',
#  'lot_config',
#  'land_slope',
#  'neighborhood',
#  'condition_1',
#  'condition_2',
#  'bldg_type',
#  'house_style',
#  'overall_qual',
#  'overall_cond',
#  'year_built',
#  'year_remod/add',
#  'roof_style',
#  'roof_matl',
#  'exterior_1st',
#  'exterior_2nd',
#  'mas_vnr_type',
#  'mas_vnr_area',
#  'exter_qual',
#  'exter_cond',
#  'foundation',
#  'bsmt_qual',
#  'bsmt_cond',
#  'bsmt_exposure',
#  'bsmtfin_type_1',
#  'bsmtfin_sf_1',
#  'bsmtfin_type_2',
#  'bsmtfin_sf_2',
#  'bsmt_unf_sf',
#  'total_bsmt_sf',
#  'heating',
#  'heating_qc',
#  'central_air',
#  'electrical',
#  '1st_flr_sf',
#  '2nd_flr_sf',
#  'low_qual_fin_sf',
#  'gr_liv_area',
#  'bsmt_full_bath',
#  'bsmt_half_bath',
#  'full_bath',
#  'half_bath',
#  'bedroom_abvgr',
#  'kitchen_abvgr',
#  'kitchen_qual',
#  'totrms_abvgrd',
#  'functional',
#  'fireplaces',
#  'fireplace_qu',
#  'garage_type',
#  'garage_yr_blt',
#  'garage_finish',
#  'garage_cars',
#  'garage_area',
#  'garage_qual',
#  'garage_cond',
#  'paved_drive',
#  'wood_deck_sf',
#  'open_porch_sf',
#  'enclosed_porch',
#  '3ssn_porch',
#  'screen_porch',
#  'pool_area',
#  'pool_qc',
#  'fence',
#  'misc_feature',
#  'misc_val',
#  'mo_sold',
#  'yr_sold',
#  'sale_type',
#  'neighborhood_Blueste',
#  'neighborhood_BrDale',
#  'neighborhood_BrkSide',
#  'neighborhood_ClearCr',
#  'neighborhood_CollgCr',
#  'neighborhood_Crawfor',
#  'neighborhood_Edwards',
#  'neighborhood_Gilbert',
#  'neighborhood_Greens',
#  'neighborhood_IDOTRR',
#  'neighborhood_MeadowV',
#  'neighborhood_Mitchel',
#  'neighborhood_NAmes',
#  'neighborhood_NPkVill',
#  'neighborhood_NWAmes',
#  'neighborhood_NoRidge',
#  'neighborhood_NridgHt',
#  'neighborhood_OldTown',
#  'neighborhood_SWISU',
#  'neighborhood_Sawyer',
#  'neighborhood_SawyerW',
#  'neighborhood_Somerst',
#  'neighborhood_StoneBr',
#  'neighborhood_Timber',
#  'neighborhood_Veenker',
#  'neighborhood_GrnHill',
#  'neighborhood_Landmrk',
#  'y_hat',
#  'fbxgrla',
#  'frxgrla',
#  'nb_ranking',
#  'nbrkxgla',
#  'ovqxgla',
#  'ovqxnbr',
#  'carsxara']

# %%
X_TEST = df_test[features]

# %% [markdown]
# X_TEST_SC = ss.transform(X_TEST)

# %% [markdown]
# #### Create Predictions

# %%
df_test['y_hat'] = lr.predict(X_TEST)

# %%
df_test.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   alley lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    year_built  year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 0             0         1020           1020    GasA         Gd           N
# 1             0         1967           1967    GasA         TA           Y
# 2             0          100            654    GasA         Ex           Y
# 3             0          968            968    GasA         TA           Y
# 4             0          785           1394    GasA         Gd           Y
#
#   electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 0              2           Fa              9        Typ           0
# 1              2           TA             10        Typ           0
# 2              1           Gd              7        Typ           1
# 3              1           TA              5        Typ           0
# 4              1           TA              6        Typ           2
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 0          NaN      Detchd         1910.0           Unf            1
# 1          NaN      Attchd         1977.0           Fin            2
# 2           Gd      Attchd         2006.0           RFn            2
# 3          NaN      Detchd         1935.0           Unf            2
# 4           Gd      Attchd         1963.0           RFn            2
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 0          440          Po          Po           Y             0
# 1          580          TA          TA           Y           170
# 2          426          TA          TA           Y           100
# 3          480          Fa          TA           N             0
# 4          514          TA          TA           Y             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area pool_qc  \
# 0             60             112           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2             24               0           0             0          0     NaN
# 3              0             184           0             0          0     NaN
# 4             76               0           0           185          0     NaN
#
#   fence misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 0   NaN          NaN         0        4     2006       WD
# 1   NaN          NaN         0        8     2006       WD
# 2   NaN          NaN         0        9     2006       New
# 3   NaN          NaN         0        7     2007       WD
# 4   NaN          NaN         0        7     2009       WD
#
#    neighborhood_Blueste  neighborhood_BrDale  neighborhood_BrkSide  \
# 0                     0                    0                     0
# 1                     0                    0                     0
# 2                     0                    0                     0
# 3                     0                    0                     0
# 4                     0                    0                     0
#
#    neighborhood_ClearCr  neighborhood_CollgCr  neighborhood_Crawfor  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    neighborhood_Edwards  neighborhood_Gilbert  neighborhood_Greens  \
# 0                     0                     0                    0
# 1                     0                     0                    0
# 2                     0                     1                    0
# 3                     0                     0                    0
# 4                     0                     0                    0
#
#    neighborhood_IDOTRR  neighborhood_MeadowV  neighborhood_Mitchel  \
# 0                    0                     0                     0
# 1                    0                     0                     0
# 2                    0                     0                     0
# 3                    0                     0                     0
# 4                    0                     0                     0
#
#    neighborhood_NAmes  neighborhood_NPkVill  neighborhood_NWAmes  \
# 0                   0                     0                    0
# 1                   0                     0                    0
# 2                   0                     0                    0
# 3                   0                     0                    0
# 4                   1                     0                    0
#
#    neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# 0                     0                     0                     1
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     1
# 4                     0                     0                     0
#
#    neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# 0                   0                    0                     0
# 1                   0                    1                     0
# 2                   0                    0                     0
# 3                   0                    0                     0
# 4                   0                    0                     0
#
#    neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# 0                     0                     0                    0
# 1                     0                     0                    0
# 2                     0                     0                    0
# 3                     0                     0                    0
# 4                     0                     0                    0
#
#    neighborhood_Veenker  neighborhood_GrnHill  neighborhood_Landmrk  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#            y_hat  fbxgrla  frxgrla  nb_ranking  nbrkxgla  ovqxgla  ovqxnbr  \
# 0  130252.861279     3856        0        1.85    3566.8    11568    11.10
# 1  176218.079076     3934        0        1.40    2753.8     9835     7.00
# 2  189039.286049     2992     1496        2.10    3141.6    10472    14.70
# 3  123791.509736      968        0        1.85    1790.8     4840     9.25
# 4  183440.319589     1394     2788        1.90    2648.6     8364    11.40
#
#    carsxara
# 0       440
# 1      1160
# 2       852
# 3       960
# 4      1028

# %%
df_test.shape
# Out:
# (878, 115)

# %% [markdown]
# # Create Submission

# %%
nars_submission = df_test[['id', 'y_hat']]

# %% [markdown]
# # View Correct Submission Format

# %%
nars_submission.head()
# Out:
#      id          y_hat
# 0  2658  130252.861279
# 1  2718  176218.079076
# 2  2414  189039.286049
# 3  1989  123791.509736
# 4   625  183440.319589

# %%
nars_submission.shape
# Out:
# (878, 2)

# %% [markdown]
# # Rename columns of the fisrt submission

# %%
nars_submission.rename(columns = {'id' : 'Id',
                                     'y_hat' : 'SalePrice'}, inplace = True)
# Out:
# /Users/narschang/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
nars_submission.shape
# Out:
# (878, 2)

# %%
nars_submission.head()
# Out:
#      Id      SalePrice
# 0  2658  130252.861279
# 1  2718  176218.079076
# 2  2414  189039.286049
# 3  1989  123791.509736
# 4   625  183440.319589

# %% [markdown]
# #### Export as a CSV

# %%
nars_submission.to_csv('nars_submission_19.csv', index = False)

# %% [markdown]
# # Sample submission reference

# %% [markdown]
# sample_submission = pd.read_csv('sample_sub_reg.csv')
# sample_submission.shape

# %% [markdown]
# sample_submission.head()

# %% [markdown]
# ![Screen%20Shot%202020-10-04%20at%208.06.43%20PM.png](attachment:Screen%20Shot%202020-10-04%20at%208.06.43%20PM.png)
